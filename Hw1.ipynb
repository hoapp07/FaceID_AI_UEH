# %% [markdown]
# <a href="https://colab.research.google.com/github/hoapp07/FaceID_AI_UEH/blob/main/Hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#23.1
import folium
m=folium.Map(location=[10.761097765603395, 106.66834914776304],zoom_start=13)
folium.Marker([10.761097765603395, 106.66834914776304], popup="UEH",tooltip="Click vào", icon=folium.Icon(color='red')).add_to(m)
folium.Marker([10.75796490581001, 106.65954962108378], popup="Bệnh viện Chợ Rẫy", tooltip="Click vào").add_to(m)
folium.Marker([10.771803963801421, 106.66966154911657], popup="Vạn Hạnh Mall", tooltip="Click vào").add_to(m)
folium.Marker([10.761306153121895, 106.67272463181955], popup="Chùa Giác Ngộ", tooltip="Click vào").add_to(m)
folium.Marker([10.761179671241916, 106.6633583581005], popup="Sân vận động Thống Nhất", tooltip="Click vào").add_to(m)
folium.Marker([10.763834469421207, 106.66833015453257], popup="Văn phòng Kinh tế và Văn hóa Đài Bắc", tooltip="Click vào").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f70075858ca8a4f6d567ac4d24518068 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f70075858ca8a4f6d567ac4d24518068&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f70075858ca8a4f6d567ac4d24518068 = L.map(
#                 &quot;map_f70075858ca8a4f6d567ac4d24518068&quot;,
#                 {
#                     center: [10.761097765603395, 106.66834914776304],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc5c7571d5b7f77bbe809909b805f6a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc5c7571d5b7f77bbe809909b805f6a7.addTo(map_f70075858ca8a4f6d567ac4d24518068);
#
#
#             var marker_a85c4708e404f6d3b32f36d72f3e0954 = L.marker(
#                 [10.761097765603395, 106.66834914776304],
#                 {
# }
#             ).addTo(map_f70075858ca8a4f6d567ac4d24518068);
#
#
#             var icon_87515448ba7fd5eeaaa6c4be077b9141 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6eb84dfb238590959e6e1b0230b493b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f8a2e7597102376c5ceecc40a3c5568 = $(`&lt;div id=&quot;html_5f8a2e7597102376c5ceecc40a3c5568&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UEH&lt;/div&gt;`)[0];
#                 popup_6eb84dfb238590959e6e1b0230b493b0.setContent(html_5f8a2e7597102376c5ceecc40a3c5568);
#
#
#
#         marker_a85c4708e404f6d3b32f36d72f3e0954.bindPopup(popup_6eb84dfb238590959e6e1b0230b493b0)
#         ;
#
#
#
#
#             marker_a85c4708e404f6d3b32f36d72f3e0954.bindTooltip(
#                 `&lt;div&gt;
#                      Click vào
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a85c4708e404f6d3b32f36d72f3e0954.setIcon(icon_87515448ba7fd5eeaaa6c4be077b9141);
#
#
#             var marker_6575df1df624d070823646a725e10dae = L.marker(
#                 [10.75796490581001, 106.65954962108378],
#                 {
# }
#             ).addTo(map_f70075858ca8a4f6d567ac4d24518068);
#
#
#         var popup_4942d16be7b3ab8575739df574011ad1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4795087e37e67d12949d9cc64be6b4b0 = $(`&lt;div id=&quot;html_4795087e37e67d12949d9cc64be6b4b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bệnh viện Chợ Rẫy&lt;/div&gt;`)[0];
#                 popup_4942d16be7b3ab8575739df574011ad1.setContent(html_4795087e37e67d12949d9cc64be6b4b0);
#
#
#
#         marker_6575df1df624d070823646a725e10dae.bindPopup(popup_4942d16be7b3ab8575739df574011ad1)
#         ;
#
#
#
#
#             marker_6575df1df624d070823646a725e10dae.bindTooltip(
#                 `&lt;div&gt;
#                      Click vào
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_b92aff74a06662960f18a8c62559a0b7 = L.marker(
#                 [10.771803963801421, 106.66966154911657],
#                 {
# }
#             ).addTo(map_f70075858ca8a4f6d567ac4d24518068);
#
#
#         var popup_42f7447033ab9a6330adec2547ba0791 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7add9ea0e8b4503ccda7d2f50db0c35 = $(`&lt;div id=&quot;html_c7add9ea0e8b4503ccda7d2f50db0c35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vạn Hạnh Mall&lt;/div&gt;`)[0];
#                 popup_42f7447033ab9a6330adec2547ba0791.setContent(html_c7add9ea0e8b4503ccda7d2f50db0c35);
#
#
#
#         marker_b92aff74a06662960f18a8c62559a0b7.bindPopup(popup_42f7447033ab9a6330adec2547ba0791)
#         ;
#
#
#
#
#             marker_b92aff74a06662960f18a8c62559a0b7.bindTooltip(
#                 `&lt;div&gt;
#                      Click vào
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1c94a358019d486cfd9bf3d50bba02dc = L.marker(
#                 [10.761306153121895, 106.67272463181955],
#                 {
# }
#             ).addTo(map_f70075858ca8a4f6d567ac4d24518068);
#
#
#         var popup_a

# %%
#23.2
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
import folium
geolocator = Nominatim(user_agent="geoapi", timeout=10)
# Điểm trung tâm ( Dinh Độc Lập )
location = geolocator.geocode("Independence Palace, Ho Chi Minh City")
center_coord=(location.latitude, location.longitude)
print(f"Tên: {location.address}")
print(f"Tọa độ: {location.latitude}, {location.longitude}")
# Danh sách 10 địa chỉ cụ thể
addresses = [
    "Ben Thanh Market, Ho Chi Minh City",
    "Tan Son Nhat Airport, Ho Chi Minh City",
    "Notre Dame Cathedral, Ho Chi Minh City",
    "Bitexco Financial Tower, Ho Chi Minh City",
    "War Remnants Museum, Ho Chi Minh City",
    "Thao Cam Vien, Ho Chi Minh City",
    "Landmark 81, Ho Chi Minh City",
    "Van Hanh Mall, Ho Chi Minh City",
    "Suoi Tien Park, Ho Chi Minh City",
    "Dam Sen Park, Ho Chi Minh City"
]
#Lấy tọa độ từng địa chỉ và tính khoảng cách đến Dinh ĐL
locations=[]
for addr in addresses:
   loc = geolocator.geocode(addr)
   coord=(loc.latitude, loc.longitude)
   dist=geodesic(center_coord, coord).km
   locations.append((addr, coord, dist))
   print(f"Tên: {loc.address}")
   print(f"Tọa độ: {loc.latitude}, {loc.longitude}")
   print(f"Khoảng cách thực tế: {dist:.2f} km")
m = folium.Map(location=center_coord, zoom_start=13)
folium.Marker(center_coord, popup="Dinh Doc Lap",tooltip="Click vào", icon=folium.Icon(color='red')).add_to(m)
for name, coords, dist in locations:
    folium.Marker(coords, popup=f"{name}\n{dist:.2f} km").add_to(m)
    folium.PolyLine([coords, center_coord], color="gray").add_to(m)
m
# Out:
# Tên: Dinh Độc Lập, 135, Nam Kỳ Khởi Nghĩa, Khu phố 7, Phường Bến Thành, Thủ Đức, Thành phố Hồ Chí Minh, 71009, Việt Nam
# Tọa độ: 10.7770348, 106.695488
# Tên: Chợ Bến Thành, Công trường Quách Thị Trang, Khu phố 6, Phường Bến Thành, Thủ Đức, Thành phố Hồ Chí Minh, 71009, Việt Nam
# Tọa độ: 10.7725301, 106.6980365
# Khoảng cách thực tế: 0.57 km
# Tên: Sân bay quốc tế Tân Sơn Nhất, Hẻm 112 Bạch Đằng, Phường Tân Sơn Hòa, Thủ Đức, Thành phố Hồ Chí Minh, 70048, Việt Nam
# Tọa độ: 10.8179793, 106.6562645
# Khoảng cách thực tế: 6.24 km
# Tên: Nhà thờ Đức Bà Sài Gòn, 1, Công trường Công xã Paris, Khu phố 3, Phường Sài Gòn, Thủ Đức, Thành phố Hồ Chí Minh, 71006, Việt Nam
# Tọa độ: 10.7797687, 106.6990427
# Khoảng cách thực tế: 0.49 km
# Tên: Bitexco Financial Tower, 02, Hải Triều, Khu phố 7, Phường Sài Gòn, Thủ Đức, Thành phố Hồ Chí Minh, 72806, Việt Nam
# Tọa độ: 10.7718634, 106.7044633
# Khoảng cách thực tế: 1.14 km
# Tên: Bảo tàng Chứng tích Chiến tranh, 28, Võ Văn Tần, Khu phố 3, Phường Xuân Hòa, Thủ Đức, Thành phố Hồ Chí Minh, 70001, Việt Nam
# Tọa độ: 10.7793648, 106.6922806
# Khoảng cách thực tế: 0.44 km
# Tên: Thảo Cầm Viên, Nguyễn Thị Minh Khai, Khu phố 1, Phường Sài Gòn, Thủ Đức, Thành phố Hồ Chí Minh, 72200, Việt Nam
# Tọa độ: 10.7896064, 106.7045903
# Khoảng cách thực tế: 1.71 km
# Tên: Cửa Hàng Innisfree - Vincom Landmark 81, Trần Trọng Kim, Vinhomes Central Park, Phường Thạnh Mỹ Tây, Thủ Đức, Thành phố Hồ Chí Minh, 71108, Việt Nam
# Tọa độ: 10.7950845, 106.7219139
# Khoảng cách thực tế: 3.51 km
# Tên: Vạn Hạnh Mall, 11, Sư Vạn Hạnh, Khu phố 10, Phường Hòa Hưng, Thủ Đức, Thành phố Hồ Chí Minh, 72712, Việt Nam
# Tọa độ: 10.7704843, 106.6695631
# Khoảng cách thực tế: 2.93 km
# Tên: Khu du lịch Suối Tiên, 120, Xa lộ Hà Nội, Khu phố 34, Phường Linh Xuân, Thủ Đức, Thành phố Hồ Chí Minh, 00084, Việt Nam
# Tọa độ: 10.8618947, 106.8025939
# Khoảng cách thực tế: 15.01 km
# Tên: Công Viên Văn hóa Đầm Sen, Phường Bình Thới, Thành phố Hồ Chí Minh, Việt Nam
# Tọa độ: 10.7659103, 106.638643
# Khoảng cách thực tế: 6.34 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5824849b5c4df0762fccc6a9d090dc7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5824849b5c4df0762fccc6a9d090dc7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5824849b5c4df0762fccc6a9d090dc7d = L.map(
#                 &quot;map_5824849b5c4df0762fccc6a9d090dc7d&quot;,
#                 {
#                     center: [10.7770348, 106.695488],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_747aebd42dd977fa98bad94896ab54bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_747aebd42dd977fa98bad94896ab54bd.addTo(map_5824849b5c4df0762fccc6a9d090dc7d);
#
#
#             var marker_3eb4c81d55891d2fb4ae18ae3d8d772b = L.marker(
#                 [10.7770348, 106.695488],
#                 {
# }
#             ).addTo(map_5824849b5c4df0762fccc6a9d090dc7d);
#
#
#             var icon_1c6247924e8e7c4ee6fba14c4062fb40 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_bafea0c2f6eecdcb008105fc38459057 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dacfbfa7b53152de067f060c8cbaf9fa = $(`&lt;div id=&quot;html_dacfbfa7b53152de067f060c8cbaf9fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dinh Doc Lap&lt;/div&gt;`)[0];
#                 popup_bafea0c2f6eecdcb008105fc38459057.setContent(html_dacfbfa7b53152de067f060c8cbaf9fa);
#
#
#
#         marker_3eb4c81d55891d2fb4ae18ae3d8d772b.bindPopup(popup_bafea0c2f6eecdcb008105fc38459057)
#         ;
#
#
#
#
#             marker_3eb4c81d55891d2fb4ae18ae3d8d772b.bindTooltip(
#                 `&lt;div&gt;
#                      Click vào
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_3eb4c81d55891d2fb4ae18ae3d8d772b.setIcon(icon_1c6247924e8e7c4ee6fba14c4062fb40);
#
#
#             var marker_3aa236993b30f3d2d4cc8958f5b0f503 = L.marker(
#                 [10.7725301, 106.6980365],
#                 {
# }
#             ).addTo(map_5824849b5c4df0762fccc6a9d090dc7d);
#
#
#         var popup_73406f0b9d4a5eedb9411de939c42061 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6822a3b6961b53c7a508e790e7635c69 = $(`&lt;div id=&quot;html_6822a3b6961b53c7a508e790e7635c69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ben Thanh Market, Ho Chi Minh City 0.57 km&lt;/div&gt;`)[0];
#                 popup_73406f0b9d4a5eedb9411de939c42061.setContent(html_6822a3b6961b53c7a508e790e7635c69);
#
#
#
#         marker_3aa236993b30f3d2d4cc8958f5b0f503.bindPopup(popup_73406f0b9d4a5eedb9411de939c42061)
#         ;
#
#
#
#
#             var poly_line_77460590ba5d3d2649464a34836f5478 = L.polyline(
#                 [[10.7725301, 106.6980365], [10.7770348, 106.695488]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5824849b5c4df0762fccc6a9d090dc7d);
#
#
#             var marker_3bd71df41eed4c51842b408d0083c505 = L.marker(
#                 [10.8179793, 106.6562645],
#                 {
# }
#             ).addTo(map_5824849b5c4df0762fccc6a9d090dc7d);
#
#
#         var popup_c968db7f036c00d17b4520c73e4aa14b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbd3272791e3618263f8ea4a3f905191 = $(`&lt;div id=&quot;html_cbd3272791e3618263f8ea4a3f905191&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tan Son Nhat Airport, Ho Chi Minh City 6.24 km&lt;/div&gt;`)[0];
#                 popup_c968db7f036c00d17b4520c73e4aa14b.setContent(html_cbd3272791e3618263f8ea4a3f905191);
#
#
#
#         marker_3bd71df41eed4c51842b408d0083c505.bindPopup(popup_c968db7f036c00d17b4520c73e4aa14b)

# %%
#23.3
import folium
from folium.plugins import HeatMap
m = folium.Map(location=[10.775, 106.700], zoom_start=13)
heat_data= [
   # Khu vực Quận 1 - Trung tâm (mật độ cao)
    [10.7769, 106.7008],
    [10.7750, 106.7020],
    [10.7785, 106.6990],
    [10.7800, 106.6980],
    [10.7775, 106.7015],
    [10.7745, 106.6995],
    [10.7790, 106.7000],
    # Khu vực Quận 3 (mật độ cao)
    [10.7820, 106.6950],
    [10.7835, 106.6930],
    [10.7810, 106.6960],
    [10.7840, 106.6940],
    # Khu vực Quận 5 (mật độ trung bình)
    [10.7560, 106.6650],
    [10.7580, 106.6680],
    [10.7555, 106.6660],
    # Khu vực Quận 10 (mật độ trung bình)
    [10.7620, 106.6750],
    [10.7680, 106.6800],
    [10.7650, 106.6780],
    # Khu vực Quận 7 (mật độ trung bình - khá)
    [10.7300, 106.7100],
    [10.7350, 106.7150],
    [10.7320, 106.7120],
    [10.7380, 106.7180],
    # Khu vực Thủ Đức (mật độ thấp)
    [10.8000, 106.7200],
    [10.8100, 106.7250],
    [10.8050, 106.7220],
    # Khu vực Tân Bình (mật độ trung bình)
    [10.7900, 106.6500],
    [10.7950, 106.6400],
]
HeatMap(heat_data).add_to(m)
folium.Marker([10.7769, 106.7008],  popup="Vùng mật độ cao - Khu vực trung tâm Quận 1, 3", icon=folium.Icon(color='red')).add_to(m)
folium.Marker([10.7300, 106.7100], popup="Vùng mật độ trung bình - Quận 7", icon=folium.Icon(color='orange')).add_to(m)
folium.Marker([10.8000, 106.7200], popup="Vùng mật độ thấp - Thủ Đức", icon=folium.Icon(color='green')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ee4bcf5439d418643be025539b3be02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ee4bcf5439d418643be025539b3be02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ee4bcf5439d418643be025539b3be02 = L.map(
#                 &quot;map_7ee4bcf5439d418643be025539b3be02&quot;,
#                 {
#                     center: [10.775, 106.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f576e9cbf454e5a3dfae823ec65412d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f576e9cbf454e5a3dfae823ec65412d6.addTo(map_7ee4bcf5439d418643be025539b3be02);
#
#
#             var heat_map_0c990a2f0646c76a000a1c8bce62830f = L.heatLayer(
#                 [[10.7769, 106.7008], [10.775, 106.702], [10.7785, 106.699], [10.78, 106.698], [10.7775, 106.7015], [10.7745, 106.6995], [10.779, 106.7], [10.782, 106.695], [10.7835, 106.693], [10.781, 106.696], [10.784, 106.694], [10.756, 106.665], [10.758, 106.668], [10.7555, 106.666], [10.762, 106.675], [10.768, 106.68], [10.765, 106.678], [10.73, 106.71], [10.735, 106.715], [10.732, 106.712], [10.738, 106.718], [10.8, 106.72], [10.81, 106.725], [10.805, 106.722], [10.79, 106.65], [10.795, 106.64]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_0c990a2f0646c76a000a1c8bce62830f.addTo(map_7ee4bcf5439d418643be025539b3be02);
#
#
#             var marker_669824ab0f746e03711a1cd89099b17d = L.marker(
#                 [10.7769, 106.7008],
#                 {
# }
#             ).addTo(map_7ee4bcf5439d418643be025539b3be02);
#
#
#             var icon_c4052c9631088eeb45918429a8ae2bfb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b5a13105e7bad39213a30265666e8ff4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef04e5d526366ec92fb4d48522a53c79 = $(`&lt;div id=&quot;html_ef04e5d526366ec92fb4d48522a53c79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vùng mật độ cao - Khu vực trung tâm Quận 1, 3&lt;/div&gt;`)[0];
#                 popup_b5a13105e7bad39213a30265666e8ff4.setContent(html_ef04e5d526366ec92fb4d48522a53c79);
#
#
#
#         marker_669824ab0f746e03711a1cd89099b17d.bindPopup(popup_b5a13105e7bad39213a30265666e8ff4)
#         ;
#
#
#
#
#                 marker_669824ab0f746e03711a1cd89099b17d.setIcon(icon_c4052c9631088eeb45918429a8ae2bfb);
#
#
#             var marker_db1ab27b44201b596ffb560c52a94ab3 = L.marker(
#                 [10.73, 106.71],
#                 {
# }
#             ).addTo(map_7ee4bcf5439d418643be025539b3be02);
#
#
#             var icon_b903719e9018e588cc53928284e99989 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c64ffad492d7dae96e6a777c4526de47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3af9ae4bed0bd2c8ed764afac0b88c48 = $(`&lt;div id=&quot;html_3af9ae4bed0bd2c8ed764afac0b88c48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vùng mật độ trung bình - Quận 7&lt;/div&gt;`)[0];
#                 popup_c64ffad492d7dae96e6a777c4526de47.setContent(html_3af9ae4bed0bd2c8ed764afac0b88c48);
#
#
#
#         marker_db1ab27b44201b596ffb560c52a94ab3.bindPopup(popup_c64ffad492d7dae96e6a777c4526de47)
#         ;
#
#
#
#
#                 marker_db1ab27b44201b596ffb560c52a94ab3.setIcon(icon_b903719e9018e588cc53928284e99989);
#
#
#             var marker_1f6d8d4cb79efb7b55a498360e3eb062 = L.marker(
#                 [10.8, 106.72],
#                 {
# }
#             ).addTo(map_7ee4bcf5439d418643be025539b3be02);
#
#
#             var icon_c28741427e0cb8c6ca593c99d1ae705d = L.AwesomeMarkers.icon(
#                 {

# %%
#23.5
import folium
warehouse = [10.775, 106.700]
m = folium.Map(location=warehouse, zoom_start=13)
# Vẽ vòng tròn bán kính 3 km (màu xanh dương)
folium.Circle(location=warehouse,radius=3000,color='blue',fill=True, popup='3 km').add_to(m)
# Vẽ vòng tròn bán kính 5 km (màu xanh lá)
folium.Circle(location=warehouse,radius=5000,color='green',fill=True,popup='5 km').add_to(m)
# Vẽ vòng tròn bán kính 10 km (màu cam)
folium.Circle(location=warehouse,radius=10000,color='orange',fill=True,popup='10 km').add_to(m)
# Thêm marker cho trung tâm phân phối
folium.Marker(location=warehouse,popup='Trung tâm phân phối',icon=folium.Icon(color='red')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb4c7b7a351b60340f5c5297a9b2c1cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb4c7b7a351b60340f5c5297a9b2c1cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb4c7b7a351b60340f5c5297a9b2c1cd = L.map(
#                 &quot;map_fb4c7b7a351b60340f5c5297a9b2c1cd&quot;,
#                 {
#                     center: [10.775, 106.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17b0bc076b7dfe84c64bc1710c901f60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17b0bc076b7dfe84c64bc1710c901f60.addTo(map_fb4c7b7a351b60340f5c5297a9b2c1cd);
#
#
#             var circle_e0194cc31308a3d28a7a20833ee4c20f = L.circle(
#                 [10.775, 106.7],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fb4c7b7a351b60340f5c5297a9b2c1cd);
#
#
#         var popup_d721b9bae912dace16639f719c4e1e27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_056ca9f84145b04257595f29e99bde69 = $(`&lt;div id=&quot;html_056ca9f84145b04257595f29e99bde69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3 km&lt;/div&gt;`)[0];
#                 popup_d721b9bae912dace16639f719c4e1e27.setContent(html_056ca9f84145b04257595f29e99bde69);
#
#
#
#         circle_e0194cc31308a3d28a7a20833ee4c20f.bindPopup(popup_d721b9bae912dace16639f719c4e1e27)
#         ;
#
#
#
#
#             var circle_96cae11a1996b3ccee1240688c7e85fb = L.circle(
#                 [10.775, 106.7],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fb4c7b7a351b60340f5c5297a9b2c1cd);
#
#
#         var popup_f20ccd78d693bfcd628498068f2b0208 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c28d2ca23c5d11db2781f65d09cb566d = $(`&lt;div id=&quot;html_c28d2ca23c5d11db2781f65d09cb566d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5 km&lt;/div&gt;`)[0];
#                 popup_f20ccd78d693bfcd628498068f2b0208.setContent(html_c28d2ca23c5d11db2781f65d09cb566d);
#
#
#
#         circle_96cae11a1996b3ccee1240688c7e85fb.bindPopup(popup_f20ccd78d693bfcd628498068f2b0208)
#         ;
#
#
#
#
#             var circle_c15808a90af753274361bcb736da78f2 = L.circle(
#                 [10.775, 106.7],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fb4c7b7a351b60340f5c5297a9b2c1cd);
#
#
#         var popup_404b4261c4df88b1ce8c6812d82d64f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c72022d97d4c6f7a81ad608cef8c7783 = $(`&lt;div id=&quot;html_c72022d97d4c6f7a81ad608cef8c7783&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;10 km&lt;/div&gt;`)[0];
#                 popup_404b4261c4df88b1ce8c6812d82d64f4.setContent(html_c72022d97d4c6f7a81ad608cef8c7783);
#
#
#
#         circle_c15808a90af753274361bcb736da78f2.bindPopup(popup_404b4261c4df88b1ce8c6812d82d64f4)
#         ;
#
#
#
#
#             var marker_5712a16c4613267c5c6091410776eccb = L.marker(
#                 [10.775, 106.7],
#                 {
# }
#             ).addTo(map_fb4c7b7a351b60340f5c5297a9b2c1

# %%
#23.6
import osmnx as ox
import folium
import geopandas as gpd
# Cấu hình cache
ox.settings.use_cache = True
# 1. Tải mạng lưới đường bộ của Quận 1
place = "District 1, Ho Chi Minh City, Vietnam"
G = ox.graph_from_place(place, network_type='drive')
# 2. Phân tích cơ bản
n_nodes = G.number_of_nodes()
n_edges = G.number_of_edges()
print(f"Số nút giao: {n_nodes}")
print(f"Số đoạn đường: {n_edges}")
# Tổng chiều dài (mét -> km)
total_length_m = sum(data['length'] for u, v, data in G.edges(data=True))
total_length_km = total_length_m / 1000
print(f"Tổng chiều dài đường: {total_length_km:.2f} km")
# Chiều dài trung bình mỗi đoạn
avg_length_m = total_length_m / n_edges
print(f"Chiều dài trung bình mỗi đoạn: {avg_length_m:.2f} mét")
# 3. Tính diện tích khu vực
gdf_place = ox.geocode_to_gdf(place)
# Chuyển sang hệ tọa độ mét
gdf_place_proj = gdf_place.to_crs(gdf_place.estimate_utm_crs())
area_m2 = gdf_place_proj.geometry.area.iloc[0]
area_km2 = area_m2 / 1_000_000
print(f"Diện tích khu vực: {area_km2:.2f} km²")
# Mật độ mạng lưới (km đường / km²)
density = total_length_km / area_km2
print(f"Mật độ mạng lưới: {density:.2f} km/km²")
# 4. Trực quan hóa bằng Folium
# Lấy tọa độ trung tâm từ ranh giới
projected_centroid_point = gdf_place_proj.geometry.centroid.iloc[0]
# Convert the shapely Point to a geopandas GeoSeries to apply to_crs
geographic_centroid_gs = gpd.GeoSeries([projected_centroid_point], crs=gdf_place_proj.crs).to_crs(gdf_place.crs)
geographic_centroid = geographic_centroid_gs.iloc[0]
center_lat = geographic_centroid.y
center_lon = geographic_centroid.x
m = folium.Map(location=[center_lat, center_lon], zoom_start=13)
# Vẽ từng edge
for u, v, data in G.edges(data=True):
    x1, y1 = G.nodes[u]['x'], G.nodes[u]['y']
    x2, y2 = G.nodes[v]['x'], G.nodes[v]['y']
    folium.PolyLine([(y1, x1), (y2, x2)], color='blue', weight=2, opacity=0.6).add_to(m)
folium.GeoJson(gdf_place.geometry.iloc[0]).add_to(m)
m
# Out:
# Số nút giao: 989
# Số đoạn đường: 2090
# Tổng chiều dài đường: 165.17 km
# Chiều dài trung bình mỗi đoạn: 79.03 mét
# Diện tích khu vực: 7.70 km²
# Mật độ mạng lưới: 21.45 km/km²
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30bc8c96efeb9febce4199b8afb62d5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30bc8c96efeb9febce4199b8afb62d5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30bc8c96efeb9febce4199b8afb62d5f = L.map(
#                 &quot;map_30bc8c96efeb9febce4199b8afb62d5f&quot;,
#                 {
#                     center: [10.77622329602135, 106.6971492415565],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0e2b2f377659cebcfb9ec660dd4b34e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a0e2b2f377659cebcfb9ec660dd4b34e.addTo(map_30bc8c96efeb9febce4199b8afb62d5f);
#
#
#             var poly_line_9975cac646cd153918964e6e7fee6edb = L.polyline(
#                 [[10.7926816, 106.6958961], [10.7926949, 106.6959923]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_30bc8c96efeb9febce4199b8afb62d5f);
#
#
#             var poly_line_b0dd10e320e9c91a284ec5da662fb5f6 = L.polyline(
#                 [[10.7926816, 106.6958961], [10.7918359, 106.6958631]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_30bc8c96efeb9febce4199b8afb62d5f);
#
#
#             var poly_line_fd155c57b9cb7acf0084a5f9dc5fb42e = L.polyline(
#                 [[10.7926816, 106.6958961], [10.7926668, 106.695803]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_30bc8c96efeb9febce4199b8afb62d5f);
#
#
#             var poly_line_4994d0eed38d9980369a7509a1b89bd2 = L.polyline(
#                 [[10.7936866, 106.6902628], [10.7935629, 106.689543]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_30bc8c96efeb9febce4199b8afb62d5f);
#
#
#             var poly_line_74b1cd3adc7375a8abb7c839ce4c0e65 = L.polyline(
#                 [[10.7935629, 106.689543], [10.793059, 106.6896267]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.6, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_30bc8c96efeb9febce4199b8afb62d5f);
#
#
#             var poly_line_7e3cfbff7a2794a97ca0031a9b586f04 = L.polyline(
#                 [[10.7935629, 106.689543], [10.7941167, 106.6894447]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArra

# %%
# !pip install folium geopy osmnx networkx
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (2.4.1)
# Collecting osmnx
#   Downloading osmnx-2.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.6.1)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2026.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy) (2.1)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.3)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (26.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->osmnx) (1.17.0)
# Downloading osmnx-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.1.0

# %%
#23.7
import osmnx as ox
import networkx as nx
import folium
from geopy.distance import geodesic
ox.settings.use_cache = True
# Tải mạng đường Quận 1
G = ox.graph_from_place("District 1, Ho Chi Minh City, Vietnam", network_type='drive')
# Tọa độ 2 điểm (Chợ Bến Thành, Dinh Độc Lập)
start = (10.7758, 106.7009)
end = (10.7769, 106.6952)
# Tìm nút gần nhất
orig = ox.distance.nearest_nodes(G, start[1], start[0])
dest = ox.distance.nearest_nodes(G, end[1], end[0])
# Heuristic cho A*
def h(u, v):
    u_coord = (G.nodes[u]['y'], G.nodes[u]['x'])
    v_coord = (G.nodes[v]['y'], G.nodes[v]['x'])
    return geodesic(u_coord, v_coord).km
# Dijkstra
path_d = nx.shortest_path(G, orig, dest, weight='length')
len_d = nx.shortest_path_length(G, orig, dest, weight='length') / 1000
# A*
path_a = nx.astar_path(G, orig, dest, heuristic=h, weight='length')
len_a = sum(G[u][v][0]['length'] for u, v in zip(path_a[:-1], path_a[1:])) / 1000
print(f"Dijkstra: {len_d:.2f} km, A*: {len_a:.2f} km")
# Vẽ bản đồ
coords_d = [(G.nodes[n]['y'], G.nodes[n]['x']) for n in path_d]
coords_a = [(G.nodes[n]['y'], G.nodes[n]['x']) for n in path_a]
m = folium.Map()
folium.PolyLine(coords_d, color='blue', weight=5).add_to(m)
folium.PolyLine(coords_a, color='red', weight=3).add_to(m)
folium.Marker(start, popup='Chợ Bến Thành').add_to(m)
folium.Marker(end, popup='Dinh Độc Lập').add_to(m)
all_points = coords_d + coords_a
m.fit_bounds([min(all_points), max(all_points)])
m
# Out:
# Dijkstra: 0.66 km, A*: 0.66 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa2884402c6a0026fde6797a5e1cbebc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa2884402c6a0026fde6797a5e1cbebc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa2884402c6a0026fde6797a5e1cbebc = L.map(
#                 &quot;map_fa2884402c6a0026fde6797a5e1cbebc&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ae445a05b982b67a7e90e5d205bbdcf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ae445a05b982b67a7e90e5d205bbdcf.addTo(map_fa2884402c6a0026fde6797a5e1cbebc);
#
#
#             var poly_line_058d89c86e84409c1eb6d5bf07d219bf = L.polyline(
#                 [[10.7756638, 106.7004291], [10.7768018, 106.6999227], [10.777776, 106.6988723], [10.7786471, 106.6979087], [10.7791384, 106.6973782], [10.7781953, 106.6964878]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_fa2884402c6a0026fde6797a5e1cbebc);
#
#
#             var poly_line_b2cfc2f7c475828b6e42a87834aad546 = L.polyline(
#                 [[10.7756638, 106.7004291], [10.7768018, 106.6999227], [10.777776, 106.6988723], [10.7786471, 106.6979087], [10.7791384, 106.6973782], [10.7781953, 106.6964878]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fa2884402c6a0026fde6797a5e1cbebc);
#
#
#             var marker_edda18aa6e8ed6f92f7fcecd032da0c1 = L.marker(
#                 [10.7758, 106.7009],
#                 {
# }
#             ).addTo(map_fa2884402c6a0026fde6797a5e1cbebc);
#
#
#         var popup_77f66c19bc9c3ae1efd2561eb0a25204 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a25521febd0b6098337c4f735345471f = $(`&lt;div id=&quot;html_a25521febd0b6098337c4f735345471f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chợ Bến Thành&lt;/div&gt;`)[0];
#                 popup_77f66c19bc9c3ae1efd2561eb0a25204.setContent(html_a25521febd0b6098337c4f735345471f);
#
#
#
#         marker_edda18aa6e8ed6f92f7fcecd032da0c1.bindPopup(popup_77f66c19bc9c3ae1efd2561eb0a25204)
#         ;
#
#
#
#
#             var marker_138ba8a6e980c75f1d2e6a8d3a959b2d = L.marker(
#                 [10.7769, 106.6952],
#                 {
# }
#             ).addTo(map_fa2884402c6a0026fde6797a5e1cbebc);
#
#
#         var popup_78891a48c7368ec4e41c716dd975cf71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2234876ccc4cde5d55274e2cd0ca586a = $(`&lt;div id=&quot;html_2234876ccc4cde5d55274e2cd0ca586a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dinh Độc Lập&lt;/div&gt;`)[0];
#                 popup_78891a48c7368ec4e41c716dd975cf71.setContent(html_2234876ccc4cde5d55274e2cd0ca586a);
#
#
#
#         marker_138ba8a6e980c75f1d2e6a8d3a959b2d.bindPopup(popup_78891a48c7368ec4e41c716dd975cf71)
#         ;
#
#
#
#
#             map_fa2884402c6a0026fde6797a5e1cbebc.fitBounds(
#                 [[10.7756638, 106.7004291], [10.7791384, 106.6973782]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#23.8
# HỆ THỐNG GÁN XE GẦN NHẤT CHO KHÁCH HÀNG
import folium
import random
from geopy.distance import geodesic
# 1. Tọa độ trung tâm khu vực (Chợ Bến Thành)
center = (10.7758, 106.7009)
# 2. Tạo danh sách xe (ID, tọa độ)
vehicles = {
    "Xe A": (10.7700, 106.7050),
    "Xe B": (10.7800, 106.6950),
    "Xe C": (10.7850, 106.7100),
}
# 3. Tạo danh sách khách hàng
customers = {
    "Khách 1": (10.7720, 106.6980),
    "Khách 2": (10.7780, 106.7020),
    "Khách 3": (10.7820, 106.7080),
    "Khách 4": (10.7680, 106.6930),
    "Khách 5": (10.7900, 106.7150),
}
# 4. Hàm tính khoảng cách (km)
def distance(coord1, coord2):
    return geodesic(coord1, coord2).km
# 5. Ghép cặp: mỗi khách gán cho xe gần nhất
assignments = {}
for cust_name, cust_coord in customers.items():
    nearest_vehicle = None
    min_dist = float('inf')
    for veh_name, veh_coord in vehicles.items():
        d = distance(cust_coord, veh_coord)
        if d < min_dist:
            min_dist = d
            nearest_vehicle = veh_name
    assignments[cust_name] = (nearest_vehicle, min_dist)
# 6. In kết quả ghép cặp
print("=== KẾT QUẢ GHÉP XE ===")
for cust, (veh, dist) in assignments.items():
    print(f"{cust} -> {veh} (khoảng cách {dist:.2f} km)")
# 7. Vẽ bản đồ Folium
m = folium.Map(location=center, zoom_start=13)
# Vẽ các xe (màu xanh)
for veh_name, coord in vehicles.items():
    folium.Marker(
        coord,
        popup=f" {veh_name}",
        icon=folium.Icon(color='blue', icon='car', prefix='fa')
    ).add_to(m)
# Vẽ các khách (màu đỏ)
for cust_name, coord in customers.items():
    folium.Marker(
        coord,
        popup=f"{cust_name}",
        icon=folium.Icon(color='red', icon='user', prefix='fa')
    ).add_to(m)
# Vẽ đường nối từ mỗi khách đến xe được gán
for cust_name, (veh_name, dist) in assignments.items():
    cust_coord = customers[cust_name]
    veh_coord = vehicles[veh_name]
    folium.PolyLine(
        [cust_coord, veh_coord],
        color='green',
        weight=2,
        opacity=0.6,
        popup=f"{cust_name} → {veh_name} ({dist:.2f} km)"
    ).add_to(m)

all_points = list(vehicles.values()) + list(customers.values())
m.fit_bounds([min(all_points), max(all_points)])
m
# Out:
# === KẾT QUẢ GHÉP XE ===
# Khách 1 -> Xe A (khoảng cách 0.80 km)
# Khách 2 -> Xe B (khoảng cách 0.80 km)
# Khách 3 -> Xe C (khoảng cách 0.40 km)
# Khách 4 -> Xe A (khoảng cách 1.33 km)
# Khách 5 -> Xe C (khoảng cách 0.78 km)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ea4e3e3d013a2931c015dbc73347032 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ea4e3e3d013a2931c015dbc73347032&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ea4e3e3d013a2931c015dbc73347032 = L.map(
#                 &quot;map_3ea4e3e3d013a2931c015dbc73347032&quot;,
#                 {
#                     center: [10.7758, 106.7009],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be3445e48e8a484aa8acfb4e6e41a5ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be3445e48e8a484aa8acfb4e6e41a5ea.addTo(map_3ea4e3e3d013a2931c015dbc73347032);
#
#
#             var marker_3c21669c89ddc81b4aad6c4e6dfbdc5b = L.marker(
#                 [10.77, 106.705],
#                 {
# }
#             ).addTo(map_3ea4e3e3d013a2931c015dbc73347032);
#
#
#             var icon_3ea001a5652127dad2210e36eefbc950 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_664496851937387b3da42fdb9d7e9da7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad4fb446fbe7017916a08207b2d94b2e = $(`&lt;div id=&quot;html_ad4fb446fbe7017916a08207b2d94b2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; Xe A&lt;/div&gt;`)[0];
#                 popup_664496851937387b3da42fdb9d7e9da7.setContent(html_ad4fb446fbe7017916a08207b2d94b2e);
#
#
#
#         marker_3c21669c89ddc81b4aad6c4e6dfbdc5b.bindPopup(popup_664496851937387b3da42fdb9d7e9da7)
#         ;
#
#
#
#
#                 marker_3c21669c89ddc81b4aad6c4e6dfbdc5b.setIcon(icon_3ea001a5652127dad2210e36eefbc950);
#
#
#             var marker_201a0f6a587a8ea6d601d66fd907ac4b = L.marker(
#                 [10.78, 106.695],
#                 {
# }
#             ).addTo(map_3ea4e3e3d013a2931c015dbc73347032);
#
#
#             var icon_0d87e8702315021e73df8c1921f6372b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d1efcb1294f597446c5a4bd9a3e8824a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec12ca2d0a739d69a526be3c09349eec = $(`&lt;div id=&quot;html_ec12ca2d0a739d69a526be3c09349eec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; Xe B&lt;/div&gt;`)[0];
#                 popup_d1efcb1294f597446c5a4bd9a3e8824a.setContent(html_ec12ca2d0a739d69a526be3c09349eec);
#
#
#
#         marker_201a0f6a587a8ea6d601d66fd907ac4b.bindPopup(popup_d1efcb1294f597446c5a4bd9a3e8824a)
#         ;
#
#
#
#
#                 marker_201a0f6a587a8ea6d601d66fd907ac4b.setIcon(icon_0d87e8702315021e73df8c1921f6372b);
#
#
#             var marker_f8c2998c31ffde520dc50d7f14d45e42 = L.marker(
#                 [10.785, 106.71],
#                 {
# }
#             ).addTo(map_3ea4e3e3d013a2931c015dbc73347032);
#
#
#             var icon_cce56f0ded80712cde4b3c261a078bb7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;car&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_30388b88202c0d3ff0c58944f64535ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3abd66e1d02b0101a01424d769ceba9 = $(`&lt;div id=&quot;html_f3abd66e1d02b0101a01424d769ceba9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; Xe C&lt;/div&gt;`)[0];
#                 popup_30388b88202c0d3ff0c58944f64535ea.setContent(html_f3abd66e1d02b0101a01424d769ceba9);
#
#
#
#         marker_f8c2998c31ffde520dc50d7f14d45e42.bindPopup(popup_30388b88202c0d3ff0c58944f64535ea)
#         ;
#
#
#
#
#                 marker_f8c2998c31ffde520dc50d7f14d45e42.setIcon(icon_cce56f0ded80712cde4b3c261a078bb7);
#
#
#             var marker_bd8e233843a82251fc980af3cabd54c3 = L.marker(
#                 [10.772, 106.698],
#                 {
# }

# %%
#23.9
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import folium
# 1. TẠO vị trí khách hàng
np.random.seed(42)
num_customers = 200
lats = np.random.uniform(10.7, 10.9, num_customers)
lons = np.random.uniform(106.6, 106.8, num_customers)
df_customers = pd.DataFrame({
    'CustomerID': range(1, num_customers + 1),
    'Lat': lats,
    'Lon': lons
})
# 2. K-MEANS (K=3)
k = 3
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
df_customers['Cluster'] = kmeans.fit_predict(df_customers[['Lat', 'Lon']])
centroids = kmeans.cluster_centers_
df_warehouses = pd.DataFrame(centroids, columns=['Lat', 'Lon'])
df_warehouses['WarehouseID'] = range(1, k + 1)
# 3. VẼ BẢN ĐỒ FOLIUM
map_center = [df_customers['Lat'].mean(), df_customers['Lon'].mean()]
m = folium.Map(location=map_center, zoom_start=12)
# Màu sắc cho các cụm khách hàng
colors = ['#3498db', '#e74c3c', '#2ecc71']
# Vẽ khách hàng
for _, row in df_customers.iterrows():
    cluster_id = int(row['Cluster'])
    folium.CircleMarker(
        location=[row['Lat'], row['Lon']],
        radius=4,
        color=colors[cluster_id],
        fill=True,
        fill_color=colors[cluster_id],
        fill_opacity=0.7,
        popup=f"Khách hàng - Tuyến {cluster_id + 1}"
    ).add_to(m)
# Vẽ kho hàng
warehouse_colors = ['blue', 'red', 'green']
for idx, row in df_warehouses.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Lon']],
        icon=folium.Icon(color=warehouse_colors[idx], icon='home', prefix='fa'),
        popup=f"KHO TRUNG CHUYỂN",
        tooltip="Click vào"
    ).add_to(m)
# Hiển thị bản đồ
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2eea68eea5c8b3567e67284ff517947e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2eea68eea5c8b3567e67284ff517947e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2eea68eea5c8b3567e67284ff517947e = L.map(
#                 &quot;map_2eea68eea5c8b3567e67284ff517947e&quot;,
#                 {
#                     center: [10.796801246653322, 106.70087502715522],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46d53325635fca969c353fe991814564 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46d53325635fca969c353fe991814564.addTo(map_2eea68eea5c8b3567e67284ff517947e);
#
#
#             var circle_marker_84cd3868d8176b05f19cfa7d7b282366 = L.circleMarker(
#                 [10.774908023769472, 106.72840632923085],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2eea68eea5c8b3567e67284ff517947e);
#
#
#         var popup_f85816950f72af4b2cb154a957782157 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed665f39ab6de28c9573ccecb9559fe9 = $(`&lt;div id=&quot;html_ed665f39ab6de28c9573ccecb9559fe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Khách hàng - Tuyến 3&lt;/div&gt;`)[0];
#                 popup_f85816950f72af4b2cb154a957782157.setContent(html_ed665f39ab6de28c9573ccecb9559fe9);
#
#
#
#         circle_marker_84cd3868d8176b05f19cfa7d7b282366.bindPopup(popup_f85816950f72af4b2cb154a957782157)
#         ;
#
#
#
#
#             var circle_marker_afdc47280af4b25cd00270893c13f2d5 = L.circleMarker(
#                 [10.890142861281983, 106.616827992999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e74c3c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2eea68eea5c8b3567e67284ff517947e);
#
#
#         var popup_166a180d0fd2d2773fae4fc7bf85cd42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fbd0e0e27500214a4c9265efa6c97f4 = $(`&lt;div id=&quot;html_5fbd0e0e27500214a4c9265efa6c97f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Khách hàng - Tuyến 2&lt;/div&gt;`)[0];
#                 popup_166a180d0fd2d2773fae4fc7bf85cd42.setContent(html_5fbd0e0e27500214a4c9265efa6c97f4);
#
#
#
#         circle_marker_afdc47280af4b25cd00270893c13f2d5.bindPopup(popup_166a180d0fd2d2773fae4fc7bf85cd42)
#         ;
#
#
#
#
#             var circle_marker_2cdcb035cf317b15ea48d78d6bf28b6e = L.circleMarker(
#                 [10.846398788362281, 106.63232574281892],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e74c3c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2eea68eea5c8b3567e67284ff517947e);
#
#
#         var popup_f67b9164161cd2028c3102361d394afe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_542788fd07efdd647f5c0458b85d343c = $(`&lt;div id=&quot;html_542788fd07efdd647f5c0458b85d343c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Khách hàng - Tuyến 2&lt;/div&gt;`)[0];
#                 popup_f67b9164161cd2028c3102361d394afe.setContent(html_542788fd07efdd647f5c0458b85d343c);
#
#
#
#         circle_marker_2cdcb035cf317b15ea48d78d6bf28b6e.bindPopup(popup_f67b9164161cd2028c3102361d394afe

# %%
# !pip install polyline
# Out:
# Collecting polyline
#   Downloading polyline-2.0.4-py3-none-any.whl.metadata (6.5 kB)
# Downloading polyline-2.0.4-py3-none-any.whl (7.2 kB)
# Installing collected packages: polyline
# Successfully installed polyline-2.0.4

# %%
#23.10
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import folium
from folium.plugins import HeatMap
np.random.seed(42)
n_roads = 100
data = {
    'lat': np.random.uniform(10.75, 10.82, n_roads),
    'lon': np.random.uniform(106.63, 106.72, n_roads),
    'traffic_volume': np.random.randint(100, 1000, n_roads),
    'avg_speed': np.random.randint(5, 50, n_roads),
    'road_width': np.random.randint(1, 4, n_roads),
    'is_rush_hour': np.random.choice([0, 1], n_roads)
}
df = pd.DataFrame(data)
df['target_risk'] = (df['traffic_volume'] / 1000) * 0.4 + (1 - df['avg_speed'] / 50) * 0.4 + df['is_rush_hour'] * 0.2
X = df[['traffic_volume', 'avg_speed', 'road_width', 'is_rush_hour']]
y = df['target_risk']
model = RandomForestRegressor(n_estimators=50, random_state=42)
model.fit(X, y)
df['predicted_risk'] = model.predict(X)
#  TRỰC QUAN HÓA BẢN ĐỒ
m = folium.Map(location=[10.7769, 106.7009], zoom_start=13)
# Thêm HeatMap
heat_data = [[row['lat'], row['lon'], row['predicted_risk']] for index, row in df.iterrows()]
HeatMap(heat_data, radius=25, blur=15, min_opacity=0.5).add_to(m)
# ĐỀ XUẤT TUYẾN ĐƯỜNG THAY THẾ
safe_points = df[df['predicted_risk'] < 0.3].head(5)
route_coords = [[row['lat'], row['lon']] for index, row in safe_points.iterrows()]
if len(route_coords) > 1:
    folium.PolyLine(route_coords, color="green", weight=5, opacity=0.8,tooltip="Tuyến đường thay thế gợi ý (Rủi ro thấp)").add_to(m)
# Chú thích các điểm nóng
for index, row in df[df['predicted_risk'] > 0.7].head(10).iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius=6, color='red', fill=True,
        popup=f"Nguy cơ cao: {row['predicted_risk']:.2f}"
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_751d60c3a0e382573cb6ba62f6cee463 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_751d60c3a0e382573cb6ba62f6cee463&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_751d60c3a0e382573cb6ba62f6cee463 = L.map(
#                 &quot;map_751d60c3a0e382573cb6ba62f6cee463&quot;,
#                 {
#                     center: [10.7769, 106.7009],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3ece765bf89914c2dee8bb185a23ffd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b3ece765bf89914c2dee8bb185a23ffd.addTo(map_751d60c3a0e382573cb6ba62f6cee463);
#
#
#             var heat_map_3b1979f8af3c5275efd63ea6ad732516 = L.heatLayer(
#                 [[10.776217808319316, 106.6328286267118, 0.6251519999999995], [10.816550001448695, 106.68727693701373, 0.3224560000000001], [10.801239575926799, 106.65829203829686, 0.6649200000000001], [10.791906093893793, 106.67577136220483, 0.5094000000000003], [10.76092130483097, 106.71168098265335, 0.41226400000000013], [10.760919616423534, 106.65243630062339, 0.2721120000000001], [10.754065852851774, 106.6669344630732, 0.7135519999999995], [10.810632330204246, 106.69799960246887, 0.4936560000000005], [10.792078050822024, 106.65059183489424, 0.17115200000000003], [10.799565080445724, 106.63692819188459, 0.4255199999999999], [10.751440914600707, 106.65607763076224, 0.6013040000000002], [10.81789368965134, 106.64450991585285, 0.6526320000000004], [10.80827098485603, 106.71367278871082, 0.15213600000000013], [10.76486373774748, 106.70273083416079, 0.4026800000000002], [10.762727747704497, 106.68700633808594, 0.8420320000000001], [10.76283831568974, 106.70843145311689, 0.42414400000000024], [10.771296957007168, 106.70233048692091, 0.6367519999999997], [10.786732950214256, 106.64679130529974, 0.29603200000000013], [10.780236151304948, 106.71033030986409, 0.5781759999999995], [10.770386039813863, 106.6785408017724, 0.5289120000000004], [10.792829702630566, 106.70266961396476, 0.2050640000000001], [10.759764570245643, 106.7106482169931, 0.512744], [10.770450125397465, 106.65862031274746, 0.6736079999999999], [10.775645329030558, 106.63990467320748, 0.36946399999999996], [10.781924898895193, 106.65051416462877, 0.780704], [10.80496231729751, 106.66843970097636, 0.45081600000000016], [10.763977164751084, 106.70362132893302, 0.22563999999999992], [10.785996410688952, 106.70746575249306, 0.553112], [10.791469019820344, 106.63062569174781, 0.7148479999999999], [10.7532515288904, 106.67596725723197, 0.5436160000000003], [10.7925281396331, 106.66756699028339, 0.7643200000000004], [10.76193668865811, 106.64998970294236, 0.43810400000000027], [10.75455361150897, 106.64078788306003, 0.3703040000000001], [10.816421987607734, 106.66038536542632, 0.30428800000000006], [10.81759424231522, 106.71486187335212, 0.44349600000000033], [10.806587814368152, 106.65908826388187, 0.6197920000000003], [10.771322963842136, 106.6766911559569, 0.36144000000000026], [10.756837047980447, 106.69327170630056, 0.6655999999999994], [10.797896311855851, 106.66272666421413, 0.5323599999999998], [10.780810674561772, 106.71746038744489, 0.5804959999999999], [10.758542676439134, 106.71662025654479, 0.6113439999999994], [10.784662383707788, 106.65266040662428, 0.34124000000000004], [10.752407196478066, 106.67475236553031, 0.2500959999999999], [10.813652428145515, 106.6570790478835, 0.5380800000000003], [10.768114598712001, 106.65563564449397, 0.36912800000000023], [10.796376559904779, 106.6333198252619, 0.36388800000000004], [10.771819775326259, 106.6848607900582, 0.372136], [10.786404761482446, 106.67524111209059, 0.41502400000000006], [10.78826971955403, 106.6346330876125, 0.3397360000000001], [10.762939811886787, 106.65507818178129, 0.5151279999999999], [10.81787092394352, 106.711743929737, 0.6500320000000002], [10.804259297635278, 106.65156057016003, 0.3807040000000002], [10.815764925909493, 106.64304053848821, 0.30462400000000034], [10.812637914529935, 106.67405074842497, 0.6334560000000002], [10.791852998516775, 106.71870854086995, 0.2058960000000002], [10.814531196451618, 106.65178497443603, 0.6844640000000001], [10.756194475143634, 106.69049219926653, 0.7962079999999999], [10.76371880036934, 106.69854576537958, 0.17570400000000005], [10.753165910223737, 106.65138737895931, 0.6759199999999999], [10.772773123153428, 106.695539471

# %%
#23.11
import numpy as np
import pandas as pd
import folium
from sklearn.ensemble import RandomForestRegressor
# 1. Dữ liệu giả lập
np.random.seed(42)
n = 300
lat = np.random.uniform(10.7, 10.9, n)
lon = np.random.uniform(106.6, 106.8, n)
hour = np.random.randint(0, 24, n)
# Nhu cầu cao ở gần trung tâm (10.78,106.70) và giờ cao điểm (7-9, 17-19)
center_lat, center_lon = 10.78, 106.70
dist = np.sqrt((lat - center_lat)**2 + (lon - center_lon)**2)
demand = 50 * (1 - dist/0.2) + np.random.normal(0, 5, n)
peak = ((hour >= 7) & (hour <= 9)) | ((hour >= 17) & (hour <= 19))
demand[peak] += 30
demand = np.clip(demand, 0, 100)
df = pd.DataFrame({'lat': lat, 'lon': lon, 'hour': hour, 'demand': demand})
# 2. Mô hình Random Forest
X = df[['lat', 'lon', 'hour']]
y = df['demand']
model = RandomForestRegressor(n_estimators=30, random_state=42)
model.fit(X, y)
df['pred_demand'] = model.predict(X)
# 3. Phân tích nhu cầu theo khu vực
df['region'] = 'Khác'
df.loc[(lat > 10.8) & (lon < 106.7), 'region'] = 'Tây Bắc'
df.loc[(lat > 10.8) & (lon >= 106.7), 'region'] = 'Đông Bắc'
df.loc[(lat <= 10.8) & (lon < 106.7), 'region'] = 'Tây Nam'
df.loc[(lat <= 10.8) & (lon >= 106.7), 'region'] = 'Đông Nam'
region_demand = df.groupby('region')['pred_demand'].mean().sort_values(ascending=False)
print("\n=== NHU CẦU TRUNG BÌNH THEO KHU VỰC ===")
for reg, d in region_demand.items():
    print(f"{reg}: {d:.1f}")

m = folium.Map(location=[df['lat'].mean(), df['lon'].mean()], zoom_start=12)
# Màu sắc theo nhu cầu
def color(val):
    return 'green' if val < 30 else 'orange' if val < 60 else 'red'
# Vẽ các điểm khách hàng
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['lat'], row['lon']),
        radius=5,
        color=color(row['pred_demand']),
        fill=True,
        fill_opacity=0.7,
        popup=f"Nhu cầu: {row['pred_demand']:.0f} (giờ {int(row['hour'])})"
    ).add_to(m)
# Chú thích
legend_html = '''
<div style="position: fixed; bottom: 20px; right: 20px; background-color: white; padding: 8px; border-radius: 5px; font-size: 12px; z-index: 1000; box-shadow: 2px 2px 5px gray;">
<b>📊 NHU CẦU DỊCH VỤ</b><br>
🟢 Xanh: <30 (thấp)<br>
🟠 Cam: 30–60 (trung bình)<br>
🔴 Đỏ: >60 (cao)
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))
# Kết luận điều phối
print("\n=== ĐỀ XUẤT ĐIỀU PHỐI NGUỒN LỰC ===")
print("- Khu vực Đông Nam và Đông Bắc có nhu cầu cao nhất → cần nhiều xe.")
print("- Giờ cao điểm (7-9h sáng, 17-19h chiều) nhu cầu tăng ~30% → tăng cường xe.")
print("- Có thể điều xe từ vùng Tây Bắc (nhu cầu thấp) sang vùng Đông Nam.")
m
# Out:
# === NHU CẦU TRUNG BÌNH THEO KHU VỰC ===
# Tây Nam: 40.0
# Đông Nam: 38.7
# Tây Bắc: 37.1
# Đông Bắc: 34.3
#
# === ĐỀ XUẤT ĐIỀU PHỐI NGUỒN LỰC ===
# - Khu vực Đông Nam và Đông Bắc có nhu cầu cao nhất → cần nhiều xe.
# - Giờ cao điểm (7-9h sáng, 17-19h chiều) nhu cầu tăng ~30% → tăng cường xe.
# - Có thể điều xe từ vùng Tây Bắc (nhu cầu thấp) sang vùng Đông Nam.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7032d5d26b19fd1d2f3632f6bc625a7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed; bottom: 20px; right: 20px; background-color: white; padding: 8px; border-radius: 5px; font-size: 12px; z-index: 1000; box-shadow: 2px 2px 5px gray;&quot;&gt;
# &lt;b&gt;📊 NHU CẦU DỊCH VỤ&lt;/b&gt;&lt;br&gt;
# 🟢 Xanh: &lt;30 (thấp)&lt;br&gt;
# 🟠 Cam: 30–60 (trung bình)&lt;br&gt;
# 🔴 Đỏ: &gt;60 (cao)
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7032d5d26b19fd1d2f3632f6bc625a7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7032d5d26b19fd1d2f3632f6bc625a7c = L.map(
#                 &quot;map_7032d5d26b19fd1d2f3632f6bc625a7c&quot;,
#                 {
#                     center: [10.7990409198187, 106.70216630057045],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44036ea5dca052a9a13f3f5c9774f276 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_44036ea5dca052a9a13f3f5c9774f276.addTo(map_7032d5d26b19fd1d2f3632f6bc625a7c);
#
#
#             var circle_marker_a49f52ccddc51b8a00f8d3d5e9672639 = L.circleMarker(
#                 [10.774908023769472, 106.61033634423372],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7032d5d26b19fd1d2f3632f6bc625a7c);
#
#
#         var popup_9cfcf74189d315cfca0834fdb41f24ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea9bfdda9835b872fc2230debeb0ae42 = $(`&lt;div id=&quot;html_ea9bfdda9835b872fc2230debeb0ae42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nhu cầu: 31 (giờ 4)&lt;/div&gt;`)[0];
#                 popup_9cfcf74189d315cfca0834fdb41f24ba.setContent(html_ea9bfdda9835b872fc2230debeb0ae42);
#
#
#
#         circle_marker_a49f52ccddc51b8a00f8d3d5e9672639.bindPopup(popup_9cfcf74189d315cfca0834fdb41f24ba)
#         ;
#
#
#
#
#             var circle_marker_da634786576c688a8d58fd5b2e1dd85f = L.circleMarker(
#                 [10.890142861281983, 106.70627092631362],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7032d5d26b19fd1d2f3632f6bc625a7c);
#
#
#         var popup_32f260557858eb38c283eaf02dc4f8aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee8158aa0013f3eeba94832c5508e0b3 = $(`&lt;div id=&quot;html_ee8158aa0013f3eeba94832c5508e0b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nhu cầu: 54 (giờ 17)&lt;/div&gt;`)[0];
#                 popup_32f260557858eb38c283eaf02dc4f8aa.setContent(html_ee8158aa0013f3eeba94832c5508e0b3);
#
#
#
#         circle_marker_da634786576c688a8d58fd5b2e1dd85f.bindPopup(popup_32f260557858eb38c283eaf02dc4f8aa)
#         ;
#
#
#
#
#             var circle_marker_1aa77ad7f23fd2693821bfdab9f4deaf = L.circleMarker(
#                 [10.846398788362281, 106.70812702432201],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7032d5d26b19fd1d2f3632f6bc625a7c);
#
#
#         var popup_cf82ad9a3d623de14e8b9951226a8cc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad45063a8f7ea15dd040473b44b94057 = $(`&lt;div id=&quot;html_ad45063a8f7ea15dd040473b44b9

# %%
#23.12
import folium
import numpy as np
import random
from geopy.distance import geodesic
# 1. Dữ liệu
warehouses = {
    'Kho 1 (Trung tâm)': (10.7758, 106.7009),
    'Kho 2 (Tây Bắc)':   (10.7850, 106.6850),
    'Kho 3 (Đông Nam)':  (10.7700, 106.7100)
}
np.random.seed(42)
delivery_points = {}
for i in range(1, 31):
    lat = np.random.uniform(10.760, 10.790)
    lon = np.random.uniform(106.685, 106.715)
    delivery_points[f'Điểm {i}'] = (lat, lon)
def dist(p1, p2):
    return geodesic(p1, p2).km
def nearest_neighbor_route(start, points):
    unvisited = points[:]
    route = [start]
    current = start
    while unvisited:
        nearest = min(unvisited, key=lambda p: dist(current, p))
        route.append(nearest)
        current = nearest
        unvisited.remove(nearest)
    return route
# Phương án tối ưu
assign_opt = {}
for name, coord in delivery_points.items():
    d = {wh: dist(coord, wh_coord) for wh, wh_coord in warehouses.items()}
    assign_opt[name] = min(d, key=d.get)
routes_opt = {}
for wh_name, wh_coord in warehouses.items():
    points_of_wh = [delivery_points[p] for p in assign_opt if assign_opt[p] == wh_name]
    if points_of_wh:
        routes_opt[wh_name] = nearest_neighbor_route(wh_coord, points_of_wh)
    else:
        routes_opt[wh_name] = [wh_coord]
total_opt = 0
for route in routes_opt.values():
    for i in range(len(route)-1):
        total_opt += dist(route[i], route[i+1])
# Phương án ngẫu nhiên
random.seed(123)
assign_rand = {name: random.choice(list(warehouses.keys())) for name in delivery_points}
routes_rand = {}
for wh_name, wh_coord in warehouses.items():
    points_of_wh = [delivery_points[p] for p in assign_rand if assign_rand[p] == wh_name]
    if points_of_wh:
        routes_rand[wh_name] = nearest_neighbor_route(wh_coord, points_of_wh)
    else:
        routes_rand[wh_name] = [wh_coord]
total_rand = 0
for route in routes_rand.values():
    for i in range(len(route)-1):
        total_rand += dist(route[i], route[i+1])
# Vẽ bản đồ
m = folium.Map(location=[10.777, 106.700], zoom_start=14)
# Vẽ kho (màu đen)
for name, coord in warehouses.items():
    folium.Marker(coord, popup=name, icon=folium.Icon(color='black', icon='home', prefix='fa')).add_to(m)
# Vẽ điểm giao hàng (màu xám)
for name, coord in delivery_points.items():
    folium.CircleMarker(coord, radius=3, color='gray', fill=True, popup=name).add_to(m)
# Vẽ tuyến tối ưu (xanh dương)
for wh_name, route in routes_opt.items():
    folium.PolyLine(route, color='blue', weight=3, opacity=0.7, popup=f'{wh_name} (tối ưu)').add_to(m)
# Vẽ tuyến ngẫu nhiên (đỏ, nét đứt)
for wh_name, route in routes_rand.items():
    folium.PolyLine(route, color='red', weight=2, opacity=0.5, dash_array='5,5', popup=f'{wh_name} (ngẫu nhiên)').add_to(m)
# Thêm chú thích bằng HTML (cố định vị trí)
legend_html = '''
<div style="position: fixed; bottom: 30px; right: 30px; background-color: white; padding: 8px 12px; border-radius: 6px; font-size: 13px; font-family: Arial; z-index: 1000; box-shadow: 2px 2px 5px rgba(0,0,0,0.3); border: 1px solid gray;">
<b>📌 CHÚ THÍCH</b><br>
⚫ <span style="color:black">Kho hàng</span><br>
🔵 <span style="color:blue">Tuyến tối ưu (gán gần nhất + NN)</span><br>
🔴 <span style="color:red">Tuyến ngẫu nhiên (nét đứt)</span><br>
⚪ <span style="color:gray">Điểm giao hàng</span>
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))
# In đánh giá
print("="*60)
print("ĐÁNH GIÁ HIỆU QUẢ (3 kho, 30 điểm)")
print("="*60)
print(f"Tổng quãng đường tối ưu: {total_opt:.2f} km")
print(f"Tổng quãng đường ngẫu nhiên: {total_rand:.2f} km")
print(f"Tiết kiệm: {(total_rand - total_opt)/total_rand*100:.1f}%")
for wh_name, route in routes_opt.items():
    length = sum(dist(route[i], route[i+1]) for i in range(len(route)-1))
    print(f"  {wh_name}: {len(route)-1} điểm, {length:.2f} km")
m
# Out:
# ============================================================
# ĐÁNH GIÁ HIỆU QUẢ (3 kho, 30 điểm)
# ============================================================
# Tổng quãng đường tối ưu: 18.04 km
# Tổng quãng đường ngẫu nhiên: 27.67 km
# Tiết kiệm: 34.8%
#   Kho 1 (Trung tâm): 16 điểm, 10.23 km
#   Kho 2 (Tây Bắc): 5 điểm, 2.30 km
#   Kho 3 (Đông Nam): 9 điểm, 5.51 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b87633740f1020aef7bdc8a49f0291c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed; bottom: 30px; right: 30px; background-color: white; padding: 8px 12px; border-radius: 6px; font-size: 13px; font-family: Arial; z-index: 1000; box-shadow: 2px 2px 5px rgba(0,0,0,0.3); border: 1px solid gray;&quot;&gt;
# &lt;b&gt;📌 CHÚ THÍCH&lt;/b&gt;&lt;br&gt;
# ⚫ &lt;span style=&quot;color:black&quot;&gt;Kho hàng&lt;/span&gt;&lt;br&gt;
# 🔵 &lt;span style=&quot;color:blue&quot;&gt;Tuyến tối ưu (gán gần nhất + NN)&lt;/span&gt;&lt;br&gt;
# 🔴 &lt;span style=&quot;color:red&quot;&gt;Tuyến ngẫu nhiên (nét đứt)&lt;/span&gt;&lt;br&gt;
# ⚪ &lt;span style=&quot;color:gray&quot;&gt;Điểm giao hàng&lt;/span&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b87633740f1020aef7bdc8a49f0291c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b87633740f1020aef7bdc8a49f0291c = L.map(
#                 &quot;map_8b87633740f1020aef7bdc8a49f0291c&quot;,
#                 {
#                     center: [10.777, 106.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50e8ac22f8bdadd3ee85f9cc779303a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50e8ac22f8bdadd3ee85f9cc779303a7.addTo(map_8b87633740f1020aef7bdc8a49f0291c);
#
#
#             var marker_6207dd222e0b92c71d0261f14495d541 = L.marker(
#                 [10.7758, 106.7009],
#                 {
# }
#             ).addTo(map_8b87633740f1020aef7bdc8a49f0291c);
#
#
#             var icon_ce6873851b1d5ef25d1c5ceef0d6feb9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ff082ad648d1b8652e2b1b42815fb3e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e02755321424d918d8a994ea015039df = $(`&lt;div id=&quot;html_e02755321424d918d8a994ea015039df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kho 1 (Trung tâm)&lt;/div&gt;`)[0];
#                 popup_ff082ad648d1b8652e2b1b42815fb3e1.setContent(html_e02755321424d918d8a994ea015039df);
#
#
#
#         marker_6207dd222e0b92c71d0261f14495d541.bindPopup(popup_ff082ad648d1b8652e2b1b42815fb3e1)
#         ;
#
#
#
#
#                 marker_6207dd222e0b92c71d0261f14495d541.setIcon(icon_ce6873851b1d5ef25d1c5ceef0d6feb9);
#
#
#             var marker_d82f7efdb0967bcf8bba5ffb61a58380 = L.marker(
#                 [10.785, 106.685],
#                 {
# }
#             ).addTo(map_8b87633740f1020aef7bdc8a49f0291c);
#
#
#             var icon_cd6a8a02d446449ff6ff2cadccb1ef5d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5d4744cbec306545f6c92d4e1cbbe592 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e66a4f6ecd1b79808eaba0398c6e9c47 = $(`&lt;div id=&quot;html_e66a4f6ecd1b79808eaba0398c6e9c47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kho 2 (Tây Bắc)&lt;/div&gt;`)[0];
#                 popup_5d4744cbec306545f6c92d4e1cbbe592.setContent(html_e66a4f6ecd1b79808eaba0398c6e9c47);
#
#
#
#         marker_d82f7efdb0967bcf8bba5ffb61a58380.bindPopup(popup_5d4744cbec306545f6c92d4e1cbbe592)
#         ;
#
#
#
#
#                 marker_d82f7efdb0967bcf8bba5ffb61a58380.setIcon(icon_cd6a8a02d446449ff6ff2cadccb1ef5d);
#
#
#             var marker_d3079efdbd02d857522ce82a20d55290 = L.marker(
#                 [10.77, 106.71],
#                 {
# }
#             ).addTo(map_8b87633740f1020aef7bdc8a49f0291c);
#
#
#             var icon_826b76d52f96de9a9fc7ce4ad9046b00 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_45e76dd3ca8d5a343764073ac22d0285 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa3

# %%
#23.13
import folium
from folium import plugins
import numpy as np
import pandas as pd
from geopy.distance import geodesic
# Dữ liệu
warehouses = {
    'Kho Trung tâm': (10.7758, 106.7009),
    'Kho Phía Bắc':   (10.7900, 106.6950),
    'Kho Phía Nam':   (10.7650, 106.7080)
}
np.random.seed(42)
customers = {}
for i in range(1, 41):
    lat = np.random.uniform(10.758, 10.800)
    lon = np.random.uniform(106.688, 106.718)
    customers[f'KH{i}'] = (lat, lon)
def dist(p1, p2):
    return geodesic(p1, p2).km
assign = {}
for c, coord in customers.items():
    d = {wh: dist(coord, wh_coord) for wh, wh_coord in warehouses.items()}
    assign[c] = min(d, key=d.get)
def nearest_route(start, points):
    unvisited = points[:]
    route = [start]
    cur = start
    while unvisited:
        nxt = min(unvisited, key=lambda p: dist(cur, p))
        route.append(nxt)
        cur = nxt
        unvisited.remove(nxt)
    return route
routes = {}
route_lengths = {}
for wh_name, wh_coord in warehouses.items():
    pts = [customers[c] for c in assign if assign[c] == wh_name]
    if pts:
        route = nearest_route(wh_coord, pts)
        routes[wh_name] = route
        total = sum(dist(route[i], route[i+1]) for i in range(len(route)-1))
        route_lengths[wh_name] = total
    else:
        routes[wh_name] = [wh_coord]
        route_lengths[wh_name] = 0
df_stats = pd.DataFrame([
    {'Kho': wh, 'Số khách': sum(1 for c in assign if assign[c]==wh),
     'Quãng đường (km)': round(route_lengths[wh], 2)}
    for wh in warehouses
])
total_customers = len(customers)
total_distance = sum(route_lengths.values())
# Bản đồ
m = folium.Map(location=[10.777, 106.702], zoom_start=14)
# Các lớp
fg_wh = folium.FeatureGroup('🏭 Kho hàng', show=True)
for name, coord in warehouses.items():
    folium.Marker(coord, popup=name, icon=folium.Icon(color='black', icon='home', prefix='fa')).add_to(fg_wh)
fg_cus = folium.FeatureGroup('📦 Khách hàng', show=True)
for name, coord in customers.items():
    folium.CircleMarker(coord, radius=5, color='gray', fill=True,
                        popup=f'{name}<br>Kho: {assign[name]}').add_to(fg_cus)
fg_zone = folium.FeatureGroup('📍 Vùng phục vụ 500m', show=True)
zone_colors = ['blue', 'green', 'orange']
for i, (name, coord) in enumerate(warehouses.items()):
    folium.Circle(coord, radius=500, color=zone_colors[i], fill=True, fill_opacity=0.1).add_to(fg_zone)
fg_route = folium.FeatureGroup('🚚 Tuyến giao hàng', show=True)
route_colors = ['#1f77b4', '#ff7f0e', '#2ca02c']
for i, (name, route) in enumerate(routes.items()):
    folium.PolyLine(route, color=route_colors[i], weight=4, opacity=0.8,
                    popup=f'{name}<br>Dài {route_lengths[name]:.2f} km').add_to(fg_route)
fg_wh.add_to(m); fg_cus.add_to(m); fg_zone.add_to(m); fg_route.add_to(m)
# LayerControl (góc dưới phải)
folium.LayerControl(collapsed=False, position='bottomright').add_to(m)
plugins.Fullscreen().add_to(m)
plugins.MeasureControl(position='topleft', primary_length_unit='kilometers').add_to(m)
# Bảng KPI (góc trên phải)
kpi_html = f'''
<div style="position: fixed; top: 10px; right: 10px; width: 270px; background: white; padding: 8px; border-radius: 8px; z-index: 1000; box-shadow: 0 0 10px gray; font-size: 12px;">
<b>📊 CHỈ SỐ QUẢN TRỊ</b><hr style="margin:4px 0">
👥 Tổng khách: {total_customers}<br>
📏 Tổng quãng đường: {total_distance:.2f} km<br>
📦 Phân bố theo kho:<br>
&nbsp;&nbsp;• {df_stats.iloc[0]['Kho']}: {df_stats.iloc[0]['Số khách']} khách ({df_stats.iloc[0]['Quãng đường (km)']} km)<br>
&nbsp;&nbsp;• {df_stats.iloc[1]['Kho']}: {df_stats.iloc[1]['Số khách']} khách ({df_stats.iloc[1]['Quãng đường (km)']} km)<br>
&nbsp;&nbsp;• {df_stats.iloc[2]['Kho']}: {df_stats.iloc[2]['Số khách']} khách ({df_stats.iloc[2]['Quãng đường (km)']} km)<br>
<hr style="margin:4px 0">
</div>
'''
m.get_root().html.add_child(folium.Element(kpi_html))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6157ffb9fdb8d8b2495c775ef80d1ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed; top: 10px; right: 10px; width: 270px; background: white; padding: 8px; border-radius: 8px; z-index: 1000; box-shadow: 0 0 10px gray; font-size: 12px;&quot;&gt;
# &lt;b&gt;📊 CHỈ SỐ QUẢN TRỊ&lt;/b&gt;&lt;hr style=&quot;margin:4px 0&quot;&gt;
# 👥 Tổng khách: 40&lt;br&gt;
# 📏 Tổng quãng đường: 25.43 km&lt;br&gt;
# 📦 Phân bố theo kho:&lt;br&gt;
# &amp;nbsp;&amp;nbsp;• Kho Trung tâm: 14 khách (9.29 km)&lt;br&gt;
# &amp;nbsp;&amp;nbsp;• Kho Phía Bắc: 12 khách (7.93 km)&lt;br&gt;
# &amp;nbsp;&amp;nbsp;• Kho Phía Nam: 14 khách (8.21 km)&lt;br&gt;
# &lt;hr style=&quot;margin:4px 0&quot;&gt;
#
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6157ffb9fdb8d8b2495c775ef80d1ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6157ffb9fdb8d8b2495c775ef80d1ee = L.map(
#                 &quot;map_e6157ffb9fdb8d8b2495c775ef80d1ee&quot;,
#                 {
#                     center: [10.777, 106.702],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a082a3295d25243774362835aa79c0f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a082a3295d25243774362835aa79c0f.addTo(map_e6157ffb9fdb8d8b2495c775ef80d1ee);
#
#
#             var feature_group_876357fd20b7a0bfb8c86c0a7eb662f9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7213d5d2aa961c00c93be650461b0e31 = L.marker(
#                 [10.7758, 106.7009],
#                 {
# }
#             ).addTo(feature_group_876357fd20b7a0bfb8c86c0a7eb662f9);
#
#
#             var icon_ca2fbc8eaae764bca0a3493ea879a322 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_460397f2beb973832a41f3fefee386e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34ac7b2581f220bff34694996c702292 = $(`&lt;div id=&quot;html_34ac7b2581f220bff34694996c702292&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kho Trung tâm&lt;/div&gt;`)[0];
#                 popup_460397f2beb973832a41f3fefee386e9.setContent(html_34ac7b2581f220bff34694996c702292);
#
#
#
#         marker_7213d5d2aa961c00c93be650461b0e31.bindPopup(popup_460397f2beb973832a41f3fefee386e9)
#         ;
#
#
#
#
#                 marker_7213d5d2aa961c00c93be650461b0e31.setIcon(icon_ca2fbc8eaae764bca0a3493ea879a322);
#
#
#             var marker_6803a772a684ce7f2faa93c361ba808a = L.marker(
#                 [10.79, 106.695],
#                 {
# }
#             ).addTo(feature_group_876357fd20b7a0bfb8c86c0a7eb662f9);
#
#
#             var icon_27dad7a86d242aa2c1a0ae69c4c337ab = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a960944d8c52f77d797127b522cb281d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab76d5c1e2b10cd9540f62a30b671727 = $(`&lt;div id=&quot;html_ab76d5c1e2b10cd9540f62a30b671727&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kho Phía Bắc&lt;/div&gt;`)[0];
#                 popup_a960944d8c52f77d797127b522cb281d.setContent(html_ab76d5c1e2b10cd9540f62a30b671727);
#
#
#
#         marker_6803a772a684ce7f2faa93c361ba808a.bindPopup(popup_a960944d8c52f77d797127b522cb281d)
#         ;
#
#
#
#
#                 marker_6803a772a684ce7f2faa93c361ba808a.setIcon(icon_27dad7a86d242aa2c1a0ae69c4c337ab);
#
#
#             var marker_762b18

# %%
#23.14
import folium
import numpy as np
import time
from IPython.display import clear_output, display
from geopy.distance import geodesic
# 1. XÂY DỰNG MẠNG LƯỚI ĐƯỜNG ĐƠN GIẢN (DẠNG LƯỚI Ô VUÔNG)
# Tạo các nút giao
lat_min, lat_max = 10.765, 10.790
lon_min, lon_max = 106.690, 106.715
num_nodes = 5
lats = np.linspace(lat_min, lat_max, num_nodes)
lons = np.linspace(lon_min, lon_max, num_nodes)
nodes = {}
idx = 0
for i, lat in enumerate(lats):
    for j, lon in enumerate(lons):
        nodes[(i, j)] = (lat, lon)
        idx += 1
# Kết nối các nút lân cận tạo thành mạng lưới đường
edges = []
for i in range(num_nodes):
    for j in range(num_nodes):
        if i < num_nodes-1:
            edges.append(((i, j), (i+1, j)))
        if j < num_nodes-1:
            edges.append(((i, j), (i, j+1)))
# 2. TẠO CÁC XE VÀ HÀNH TRÌNH
class Vehicle:
    def __init__(self, id, start_node, dest_node, color):
        self.id = id
        self.start = start_node
        self.dest = dest_node
        self.color = color
        self.current = start_node
        self.path = self.find_path(start_node, dest_node)
        self.step = 0
    def find_path(self, start, dest):
        # Tìm đường đi ngắn nhất
        from collections import deque
        queue = deque([(start, [start])])
        visited = set([start])
        while queue:
            node, path = queue.popleft()
            if node == dest:
                return path
            # tìm các nút lân cận
            for (a,b) in edges:
                if a == node and b not in visited:
                    visited.add(b)
                    queue.append((b, path+[b]))
                elif b == node and a not in visited:
                    visited.add(a)
                    queue.append((a, path+[a]))
        return [start]
    def move(self):
        if self.step < len(self.path)-1:
            self.step += 1
            self.current = self.path[self.step]
            return True
        return False
    def get_position(self):
        return nodes[self.current]
    def is_arrived(self):
        return self.step >= len(self.path)-1
# Khởi tạo xe:
vehicles = [
    Vehicle(1, (0,0), (4,4), 'red'),
    Vehicle(2, (0,4), (4,0), 'blue'),
    Vehicle(3, (2,0), (2,4), 'green')
]
# 3. HÀM VẼ BẢN ĐỒ TẠI MỘT THỜI ĐIỂM
def draw_map(step_count, vehicles):
    # Tạo bản đồ trung tâm
    center = ((lat_min+lat_max)/2, (lon_min+lon_max)/2)
    m = folium.Map(location=center, zoom_start=14)
    # Vẽ các nút giao (điểm màu xám)
    for node, coord in nodes.items():
        folium.CircleMarker(coord, radius=3, color='gray', fill=True, popup=str(node)).add_to(m)
    # Vẽ các cạnh (đường phố)
    for (a,b) in edges:
        coord_a = nodes[a]
        coord_b = nodes[b]
        folium.PolyLine([coord_a, coord_b], color='gray', weight=2, opacity=0.5).add_to(m)
    # Vẽ các xe (marker lớn hơn, màu sắc riêng)
    for v in vehicles:
        pos = v.get_position()
        folium.Marker(
            pos,
            popup=f"Xe {v.id} (đến {v.dest})",
            icon=folium.Icon(color=v.color, icon='car', prefix='fa')
        ).add_to(m)
    # Thêm tiêu đề bước thời gian
    title = f'<div style="position: fixed; top: 10px; left: 50px; background: white; padding: 5px; border-radius: 5px;">Bước thời gian: {step_count}</div>'
    m.get_root().html.add_child(folium.Element(title))
    # Chú thích
    legend = '''
    <div style="position: fixed; bottom: 20px; right: 20px; background: white; padding: 5px; font-size: 12px; border-radius: 5px;">
    🚗 Xe đỏ, xanh, lục đang di chuyển theo đường kẻ xám
    </div>
    '''
    m.get_root().html.add_child(folium.Element(legend))
    return m
# 4. CHẠY MÔ PHỎNG THEO BƯỚC THỜI GIAN
print("BẮT ĐẦU MÔ PHỎNG...")
step = 0
max_steps = 15
all_arrived = False
while not all_arrived and step < max_steps:
    # Xóa output cũ và vẽ bản đồ mới
    clear_output(wait=True)
    m = draw_map(step, vehicles)
    display(m)
    # Di chuyển từng xe
    arrived_count = 0
    for v in vehicles:
        if not v.is_arrived():
            v.move()
        if v.is_arrived():
            arrived_count += 1
    if arrived_count == len(vehicles):
        all_arrived = True
        print("Tất cả xe đã đến đích!")
    step += 1
    time.sleep(1.5)
print("Mô phỏng kết thúc.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91a800f71265e53dfee5b7916c97d5f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position: fixed; top: 10px; left: 50px; background: white; padding: 5px; border-radius: 5px;&quot;&gt;Bước thời gian: 7&lt;/div&gt;
#
#     &lt;div style=&quot;position: fixed; bottom: 20px; right: 20px; background: white; padding: 5px; font-size: 12px; border-radius: 5px;&quot;&gt;
#     🚗 Xe đỏ, xanh, lục đang di chuyển theo đường kẻ xám
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91a800f71265e53dfee5b7916c97d5f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91a800f71265e53dfee5b7916c97d5f4 = L.map(
#                 &quot;map_91a800f71265e53dfee5b7916c97d5f4&quot;,
#                 {
#                     center: [10.7775, 106.7025],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e613b62f47858e956058727b65047409 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e613b62f47858e956058727b65047409.addTo(map_91a800f71265e53dfee5b7916c97d5f4);
#
#
#             var circle_marker_410e661ae997943c8b16fd4caa5dcf07 = L.circleMarker(
#                 [10.765, 106.69],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_91a800f71265e53dfee5b7916c97d5f4);
#
#
#         var popup_c1c025bcb919f6f75216b0677cb8871f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_007546261a8d63a58e5a74a5a6e9543b = $(`&lt;div id=&quot;html_007546261a8d63a58e5a74a5a6e9543b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(0, 0)&lt;/div&gt;`)[0];
#                 popup_c1c025bcb919f6f75216b0677cb8871f.setContent(html_007546261a8d63a58e5a74a5a6e9543b);
#
#
#
#         circle_marker_410e661ae997943c8b16fd4caa5dcf07.bindPopup(popup_c1c025bcb919f6f75216b0677cb8871f)
#         ;
#
#
#
#
#             var circle_marker_5028a26f3feb0e32acdbf8f8f9b3495b = L.circleMarker(
#                 [10.765, 106.69624999999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_91a800f71265e53dfee5b7916c97d5f4);
#
#
#         var popup_379eb8a07b78d08df404b4907df86926 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6054c4770d7dda5d780be52ef76da164 = $(`&lt;div id=&quot;html_6054c4770d7dda5d780be52ef76da164&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(0, 1)&lt;/div&gt;`)[0];
#                 popup_379eb8a07b78d08df404b4907df86926.setContent(html_6054c4770d7dda5d780be52ef76da164);
#
#
#
#         circle_marker_5028a26f3feb0e32acdbf8f8f9b3495b.bindPopup(popup_379eb8a07b78d08df404b4907df86926)
#         ;
#
#
#
#
#             var circle_marker_b7c8cbd8ecef0037f088477ef7d98a44 = L.circleMarker(
#                 [10.765, 106.7025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_91a800f71265e53dfee5b7916c97d5f4);
#
#
#         var popup_2e472a8d9c304d45258760098d343300 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21561c86e9c77ebb7f1ce3858711bea2 = $(`&lt;div id=&quot;html_21561c86e9c77ebb7f1ce3858711bea2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(0, 2)&
# Tất cả xe đã đến đích!
# Mô phỏng kết thúc.

# %%
#23.15
# Bài toán: Bố trí 4 trạm xe cứu thương ở Hóc Môn sao cho khoảng cách đến các điểm cấp cứu là nhỏ nhất, dựa trên 50 cuộc gọi gần đây.
import numpy as np
import pandas as pd
import folium
from sklearn.cluster import KMeans
from geopy.distance import geodesic
# 1. Dữ liệu 50 cuộc gọi tại Hóc Môn
np.random.seed(42)
center = (10.879, 106.589)
calls = []
for _ in range(50):
    lat = center[0] + np.random.normal(0, 0.025)
    lon = center[1] + np.random.normal(0, 0.025)
    calls.append([lat, lon])
df = pd.DataFrame(calls, columns=['lat', 'lon'])
# 2. Phân cụm 4 trạm
k = 4
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
df['cluster'] = kmeans.fit_predict(df[['lat', 'lon']])
centroids = kmeans.cluster_centers_
# 3. Thống kê nhanh
print("=== 4 TRẠM XE CỨU THƯƠNG TẠI HÓC MÔN ===")
print(f"Tổng cuộc gọi: {len(df)}")
for i in range(k):
    print(f"Trạm {i+1}: {(df['cluster']==i).sum()} cuộc gọi")
# 4. Đánh giá
df['dist_km'] = df.apply(lambda r: min(geodesic((r.lat,r.lon), (c[0],c[1])).km for c in centroids), axis=1)
print(f"Khoảng cách TB: {df['dist_km'].mean():.2f} km")
print(f"Tỷ lệ trong 1km: {(df['dist_km']<=1).mean()*100:.1f}%")
# 5. Bản đồ với màu sắc theo cụm
m = folium.Map(location=center, zoom_start=12)
colors = ['red', 'blue', 'green', 'orange']
# Vẽ cuộc gọi
for _, r in df.iterrows():
    folium.CircleMarker(
        (r.lat, r.lon),
        radius=3,
        color=colors[int(r['cluster'])],
        fill=True,
        fill_opacity=0.6,
        popup=f"Trạm {int(r['cluster'])+1}"
    ).add_to(m)
# Vẽ trạm
for i, (lat, lon) in enumerate(centroids):
    folium.Marker(
        (lat, lon),
        popup=f"TRẠM {i+1}",
        icon=folium.Icon(color='black', icon='medkit', prefix='fa')
    ).add_to(m)
    folium.Circle((lat, lon), radius=1000, color=colors[i], fill=True, fill_opacity=0.1).add_to(m)
m
# Out:
# === 4 TRẠM XE CỨU THƯƠNG TẠI HÓC MÔN ===
# Tổng cuộc gọi: 50
# Trạm 1: 11 cuộc gọi
# Trạm 2: 9 cuộc gọi
# Trạm 3: 18 cuộc gọi
# Trạm 4: 12 cuộc gọi
# Khoảng cách TB: 1.68 km
# Tỷ lệ trong 1km: 20.0%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b0fa7eddb59028e7ceec65dd4cf7ef6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b0fa7eddb59028e7ceec65dd4cf7ef6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b0fa7eddb59028e7ceec65dd4cf7ef6 = L.map(
#                 &quot;map_5b0fa7eddb59028e7ceec65dd4cf7ef6&quot;,
#                 {
#                     center: [10.879, 106.589],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a87d9995e6a4a1d3e1979e8b3b284453 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a87d9995e6a4a1d3e1979e8b3b284453.addTo(map_5b0fa7eddb59028e7ceec65dd4cf7ef6);
#
#
#             var circle_marker_888b06513343fb1a3edb066f12626deb = L.circleMarker(
#                 [10.89141785382528, 106.58554339247073],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5b0fa7eddb59028e7ceec65dd4cf7ef6);
#
#
#         var popup_b728c981449709232051b8077249b16e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a86724e6d31f0b6c08c90b6fca14def1 = $(`&lt;div id=&quot;html_a86724e6d31f0b6c08c90b6fca14def1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trạm 4&lt;/div&gt;`)[0];
#                 popup_b728c981449709232051b8077249b16e.setContent(html_a86724e6d31f0b6c08c90b6fca14def1);
#
#
#
#         circle_marker_888b06513343fb1a3edb066f12626deb.bindPopup(popup_b728c981449709232051b8077249b16e)
#         ;
#
#
#
#
#             var circle_marker_a99ede925f8492ca954ccc4378eb3fe6 = L.circleMarker(
#                 [10.895192213452518, 106.6270757464102],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5b0fa7eddb59028e7ceec65dd4cf7ef6);
#
#
#         var popup_5982cb898bcf449e826f4b6c6fec6612 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca39afffcea1dec530cf3df299aa607e = $(`&lt;div id=&quot;html_ca39afffcea1dec530cf3df299aa607e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trạm 1&lt;/div&gt;`)[0];
#                 popup_5982cb898bcf449e826f4b6c6fec6612.setContent(html_ca39afffcea1dec530cf3df299aa607e);
#
#
#
#         circle_marker_a99ede925f8492ca954ccc4378eb3fe6.bindPopup(popup_5982cb898bcf449e826f4b6c6fec6612)
#         ;
#
#
#
#
#             var circle_marker_7b89aca8b1f32eaf1b20d1d2ce9e38f0 = L.circleMarker(
#                 [10.873146165631915, 106.58314657607627],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5b0fa7eddb59028e7ceec65dd4cf7ef6);
#
#
#         var popup_29bae09b25e3d9697ea8b2e2994851ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27e6e489b366547cd8423a556477dae1 = $(`&lt;div id=&quot;html_27e6e489b366547cd8423a556477dae1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trạm 3&lt;/div&gt;`)[0];
#                 popup_29bae09b25e3d9697ea8b2e2994851ed.setContent(html_27e6e489b366547cd8423a556477dae1);
#
#
#
#         circle_marker_7b89aca8b1f32eaf1b20d1d2ce9e38f0.bindPopup(popup_29bae09b25e3d9697ea8b2e2994851ed)
#         ;
#
#
#
#
#             var circle_marker_b0a17a3011ea995a0
